# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("Weather Data.csv",encoding= 'unicode_escape')

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 2     01-01-2012 02:00    -1.8              -3.4         89                7
# 3     01-01-2012 03:00    -1.5              -3.2         88                6
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data.shape
# Out:
# (8784, 8)

# %%
# indesx of data
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.columns
# accessing the columns of data
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# In a data we can check all the unique values
# it applied to single column only
data['Temp_C'].unique()
# Out:
# array([ -1.8,  -1.5,  -1.4,  -1.3,  -1. ,  -0.5,  -0.2,   0.2,   0.8,
#          1.8,   2.6,   3. ,   3.8,   3.1,   3.2,   4. ,   4.4,   5.3,
#          5.2,   4.6,   3.9,   3.7,   2.9,   2.3,   2. ,   1.9,   1.5,
#          2.2,   1.7,   1.1,   0. ,  -0.7,  -2.1,  -4.1,  -4.8,  -5.6,
#         -5.8,  -7. ,  -7.4,  -9. ,  -9.7, -10.5, -11.3, -12.6, -12.9,
#        -13.3, -14. , -14.8, -15. , -15.3, -14.9, -15.1, -15.8, -16.3,
#        -16.9, -17.3, -17. , -17.1, -17.5, -17.9, -18.1, -18.5, -18.6,
#        -18.2, -17.8, -16.8, -15.2, -14.2, -13.7, -12.4, -10.2,  -9.4,
#         -8.9,  -8.4,  -7.8,  -7.6,  -9.5,  -9.6,  -8.8,  -7.5,  -5.4,
#         -5. ,  -8.2,  -7.1,  -6.1,  -6.6,  -6. ,  -4.7,  -4.4,  -5.1,
#         -4.3,  -6.7,  -9.2,  -9.8,  -9.9, -10. , -10.6, -11.8, -12. ,
#        -14.4, -12.3, -12.5, -11.7, -11.9, -11.2, -11.5, -11.6,  -9.3,
#         -8.7,  -8.5,  -8.1,  -6.9,  -6.4,  -5.7,  -5.5,  -3.7,  -3.6,
# ...

# %%
data['Weather'].unique()
# all th unique values present in the columns
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
# we can check all the unique values in a column, we can apply it in the whole dataframe,
# it can be applied in whole data as well as single column
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data['Weather'].nunique()
# Out:
# 50

# %%
data['Temp_C'].nunique()
# Out:
# 533

# %%
# count
# we can check total number of non null values in each columns
# can applied in a single column as well as in the whole dataframe
data.count()

# it means no null values in any columns
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data["Date/Time"].count()
# Out:
# 8784

# %%
data["Temp_C"].value_counts()
# Out:
# Temp_C
#  16.6    65
#  1.1     58
#  0.8     47
#  1.5     45
#  19.3    44
#          ..
# -20.7     1
# -21.0     1
#  31.8     1
#  32.6     1
# -21.3     1
# Name: count, Length: 533, dtype: int64

# %%
data["Weather"].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
x = data.drop(["Weather","Date/Time"], axis='columns')
x
# Out:
#       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  \
# 0       -1.8              -3.9         86                4            8.0
# 1       -1.8              -3.7         87                4            8.0
# 2       -1.8              -3.4         89                7            4.0
# 3       -1.5              -3.2         88                6            4.0
# 4       -1.5              -3.3         88                7            4.8
# ...      ...               ...        ...              ...            ...
# 8779     0.1              -2.7         81               30            9.7
# 8780     0.2              -2.4         83               24            9.7
# 8781    -0.5              -1.5         93               28            4.8
# 8782    -0.2              -1.8         89               28            9.7
# 8783     0.0              -2.1         86               30           11.3
#
#       Press_kPa
# 0        101.24
# 1        101.24
# 2        101.26
# ...

# %%
x.corr()
# Out:
#                     Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Temp_C            1.000000          0.932714  -0.220182        -0.061876
# Dew Point Temp_C  0.932714          1.000000   0.139494        -0.095685
# Rel Hum_%        -0.220182          0.139494   1.000000        -0.092743
# Wind Speed_km/h  -0.061876         -0.095685  -0.092743         1.000000
# Visibility_km     0.273455          0.050813  -0.633683         0.004883
# Press_kPa        -0.236389         -0.320616  -0.231424        -0.356613
#
#                   Visibility_km  Press_kPa
# Temp_C                 0.273455  -0.236389
# Dew Point Temp_C       0.050813  -0.320616
# Rel Hum_%             -0.633683  -0.231424
# Wind Speed_km/h        0.004883  -0.356613
# Visibility_km          1.000000   0.231847
# Press_kPa              0.231847   1.000000

# %%
# Find all the unique wind speed value in the data
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data['Wind Speed_km/h'].unique()
# To show all the unique values in this columns
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
data['Wind Speed_km/h'].unique().sum()
# Out:
# 1080

# %%
data["Wind Speed_km/h"].nunique()
# Out:
# 34

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
# Find the number of times when the weather is exactly clear
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.Weather.value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
data.groupby("Weather condition").get_group("Clear")
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data.query('"Weather condition" == "Clear"')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 data.query('"Weather condition" == "Clear"')
#
# File c:\Users\msnsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:4443, in DataFrame.query(self, expr, inplace, **kwargs)
#    4440 res = self.eval(expr, **kwargs)
#    4442 try:
# -> 4443     result = self.loc[res]
#    4444 except ValueError:
#    4445     # when res is multi-dimensional loc raises, but this is sometimes a
#    4446     # valid query
#    4447     result = self[res]
#
# File c:\Users\msnsu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
# Find the number of times when the wind speed was exactly 4 km/h
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data[data["Wind Speed_km/h"] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 96    01-05-2012 00:00    -8.8             -11.7         79                4
# 101   01-05-2012 05:00    -7.0              -9.5         82                4
# 146   01-07-2012 02:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
data[data["Wind Speed_km/h"] == 4].value_counts()
# Out:
# Date/Time         Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 01-01-2012 00:00  -1.8    -3.9              86         4                8.0            101.24     Fog              1
# 2/23/2012 5:00     0.4    -1.1              90         4                6.4            99.11      Fog              1
# 3/17/2012 11:00    4.1     3.8              98         4                0.6            102.34     Fog              1
# 3/17/2012 0:00     3.8     3.5              98         4                1.6            102.05     Drizzle,Fog      1
# 3/16/2012 16:00    4.3     3.5              95         4                8.0            101.53     Fog              1
#                                                                                                                   ..
# 10/13/2012 4:00   -1.9    -3.8              87         4                25.0           102.52     Mainly Clear     1
# ...

# %%
# Find all the null avlues in the data
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
# Rename the columns name Weather 
data.rename(columns={"Weather":"Weather condition"}, inplace=True)

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
# What is the mean visibility
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
data.Visibility_km.mean()
# Out:
# 27.664446721311478

# %%
# what is the standard deviation of pressure of in the data
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
# What is the variance of relative humidity in this data
data["Rel Hum_%"].var()
# if there is space in between the names then we use square brackets
# Out:
# 286.24855019850196

# %%
# Find all the instances when snow was recorded
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data["Weather condition"].value_counts()
# Out:
# Weather condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
data.query('Temp_C == -1.8').sum()
# Out:
# Date/Time            01-01-2012 00:0001-01-2012 01:0001-01-2012 02:...
# Temp_C                                                           -50.4
# Dew Point Temp_C                                                -187.7
# Rel Hum_%                                                         1975
# Wind Speed_km/h                                                    412
# Visibility_km                                                    769.3
# Press_kPa                                                      2836.03
# Weather condition    FogFogFreezing Drizzle,FogSnowMostly CloudyMai...
# dtype: object

# %%
data[data["Weather condition"] == "Snow"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55    01-03-2012 07:00   -14.0             -19.5         63               19
# 84    01-04-2012 12:00   -13.7             -21.7         51               11
# 86    01-04-2012 14:00   -11.3             -19.0         53                7
# 87    01-04-2012 15:00   -10.2             -16.3         61               11
# 88    01-04-2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[data["Weather condition"] == "Snow"].value_counts()
# Out:
# Date/Time         Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather condition
# 01-03-2012 07:00  -14.0   -19.5             63         19               25.0           100.95     Snow                 1
# 12-05-2012 19:00  -1.0    -8.5              57         28               25.0           101.84     Snow                 1
# 12/18/2012 8:00    0.7     0.0              95         24               2.8            99.92      Snow                 1
# 12/18/2012 7:00    0.5    -0.2              95         24               3.2            100.00     Snow                 1
# 12/18/2012 6:00    0.5    -0.4              94         24               3.6            100.07     Snow                 1
#                                                                                                                       ..
# 03-01-2012 16:00  -2.7    -5.7              80         19               2.4            100.74     Snow                 1
# ...

# %%
data[data["Weather condition"].str.contains("Snow")]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41    01-02-2012 17:00    -2.1              -9.5         57               22
# 44    01-02-2012 20:00    -5.6             -13.4         54               24
# 45    01-02-2012 21:00    -5.8             -12.8         58               26
# 47    01-02-2012 23:00    -7.4             -14.1         59               17
# 48    01-03-2012 00:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[data["Weather condition"].str.contains("Snow")].shape
# Out:
# (583, 8)

# %%
data[data["Weather condition"].str.contains("Snow")].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41    01-02-2012 17:00    -2.1              -9.5         57               22
# 44    01-02-2012 20:00    -5.6             -13.4         54               24
# 45    01-02-2012 21:00    -5.8             -12.8         58               26
# 47    01-02-2012 23:00    -7.4             -14.1         59               17
# 48    01-03-2012 00:00    -9.0             -16.0         57               28
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# ...

# %%
# Find all the wind speed above 24
data.head()
data[data["Wind Speed_km/h"] >= 24]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 22    01-01-2012 22:00     4.4               1.9         84               24
# 23    01-01-2012 23:00     5.3               2.0         79               30
# 24    01-02-2012 00:00     5.2               1.5         77               35
# 25    01-02-2012 01:00     4.6               0.0         72               39
# 26    01-02-2012 02:00     3.9              -0.9         71               32
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[data["Wind Speed_km/h"] >= 24].shape
# Out:
# (1421, 8)

# %%
data[data["Wind Speed_km/h"] >= 4].sum()
# Out:
# Date/Time            01-01-2012 00:0001-01-2012 01:0001-01-2012 02:...
# Temp_C                                                         74877.7
# Dew Point Temp_C                                               21574.3
# Rel Hum_%                                                       569630
# Wind Speed_km/h                                                 131277
# Visibility_km                                                 235077.3
# Press_kPa                                                    856119.62
# Weather condition    FogFogFreezing Drizzle,FogFreezing Drizzle,Fog...
# dtype: object

# %%
data[data["Visibility_km"] == 25]
# Check where visibility is 25 km
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 20    01-01-2012 20:00     3.2               1.3         87               19
# 21    01-01-2012 21:00     4.0               1.7         85               20
# 23    01-01-2012 23:00     5.3               2.0         79               30
# 24    01-02-2012 00:00     5.2               1.5         77               35
# 25    01-02-2012 01:00     4.6               0.0         72               39
# ...                ...     ...               ...        ...              ...
# 8762   12/31/2012 2:00   -10.1             -13.4         77                9
# 8763   12/31/2012 3:00   -11.8             -14.4         81                6
# 8764   12/31/2012 4:00   -10.5             -12.8         83               11
# 8765   12/31/2012 5:00   -10.2             -12.4         84                6
# 8766   12/31/2012 6:00    -9.7             -11.7         85                4
#
# ...

# %%
([data["Visibility_km"] == 25]) and (data[data["Wind Speed_km/h"] >= 24])
# Check where both conditions are satisfied
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 22    01-01-2012 22:00     4.4               1.9         84               24
# 23    01-01-2012 23:00     5.3               2.0         79               30
# 24    01-02-2012 00:00     5.2               1.5         77               35
# 25    01-02-2012 01:00     4.6               0.0         72               39
# 26    01-02-2012 02:00     3.9              -0.9         71               32
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# mean values against Weathear condition
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.8              -3.9         86                4
# 1  01-01-2012 01:00    -1.8              -3.7         87                4
# 2  01-01-2012 02:00    -1.8              -3.4         89                7
# 3  01-01-2012 03:00    -1.5              -3.2         88                6
# 4  01-01-2012 04:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.groupby("Wind Speed_km/h")
# Error asche

# %%
# min and max of each columns against weather condition
data.groupby("Weather condition").min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather condition
# Clear                                    01-03-2012 19:00   -23.3
# Cloudy                                   01-01-2012 17:00   -21.4
# Drizzle                                  05-01-2012 15:00     1.1
# Drizzle,Fog                              05-01-2012 16:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                      01-01-2012 00:00   -16.0
# Freezing Drizzle                         01-07-2012 11:00    -9.0
# Freezing Drizzle,Fog                     01-01-2012 02:00    -6.4
# Freezing Drizzle,Haze                    02-01-2012 11:00    -5.8
# Freezing Drizzle,Snow                    03-02-2012 12:00    -8.3
# Freezing Fog                             02-05-2012 10:00   -19.0
# ...

# %%
data.groupby("Weather condition").max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather condition
# Clear                                      9/28/2012 4:00    32.8
# Cloudy                                     9/30/2012 9:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                          12/17/2012 0:00    -2.3
# Freezing Drizzle,Fog                     12-10-2012 05:00    -0.3
# Freezing Drizzle,Haze                    02-01-2012 13:00    -5.0
# Freezing Drizzle,Snow                     12/28/2012 2:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
data[data["Weather condition"] == "Fog"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.8              -3.9         86                4
# 1     01-01-2012 01:00    -1.8              -3.7         87                4
# 4     01-01-2012 04:00    -1.5              -3.3         88                7
# 5     01-01-2012 05:00    -1.4              -3.3         87                9
# 6     01-01-2012 06:00    -1.5              -3.1         89                7
# ...                ...     ...               ...        ...              ...
# 8716   12/29/2012 4:00   -16.0             -17.2         90                6
# 8717   12/29/2012 5:00   -14.8             -15.9         91                4
# 8718   12/29/2012 6:00   -13.8             -15.3         88                4
# 8719   12/29/2012 7:00   -14.8             -16.4         88                7
# 8722  12/29/2012 10:00   -12.0             -13.3         90                7
#
# ...

# %%
data[data["Weather condition"] == "Fog"].shape
# Out:
# (150, 8)

# %%
data[(data["Weather condition"] == "Clear") & (data["Visibility_km"] > 24)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data[(data["Weather condition"] == "Clear") | (data["Visibility_km"] > 40)]
# weather is clear or visibility >40
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    01-03-2012 19:00   -16.9             -24.8         50               24
# 106   01-05-2012 10:00    -6.0             -10.0         73               17
# 107   01-05-2012 11:00    -5.6             -10.2         70               22
# 108   01-05-2012 12:00    -4.7              -9.6         69               20
# 109   01-05-2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
# last rows
data[(data["Weather condition"] == "Clear") | (data["Visibility_km"] > 40)].tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather condition
# 8749           48.3     100.92     Mostly Cloudy
# 8750           48.3     100.96      Mainly Clear
# 8751           48.3     101.05      Mainly Clear
# 8752           48.3     101.15      Mainly Clear
# 8756           25.0     101.52             Clear

# %%
data[(data["Weather condition"] == "Clear") & (data["Rel Hum_%"] > 50)]
# when weather is clear and visibility is greater than 50
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 114   01-05-2012 18:00    -7.1             -14.4         56               11
# 115   01-05-2012 19:00    -9.2             -15.4         61                7
# 116   01-05-2012 20:00    -9.8             -15.7         62                9
# 117   01-05-2012 21:00    -9.0             -14.8         63               13
# 241   01-11-2012 01:00   -10.7             -17.8         56               17
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data[(data["Weather condition"] == "Clear") & (data["Rel Hum_%"] > 50) | (data["Visibility_km"] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106   01-05-2012 10:00    -6.0             -10.0         73               17
# 107   01-05-2012 11:00    -5.6             -10.2         70               22
# 108   01-05-2012 12:00    -4.7              -9.6         69               20
# 109   01-05-2012 13:00    -4.4              -9.7         66               26
# 110   01-05-2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
